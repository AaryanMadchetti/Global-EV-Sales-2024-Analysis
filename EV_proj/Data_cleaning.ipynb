# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('IEA Global EV Data 2024.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12654 entries, 0 to 12653
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      12654 non-null  object
#  1   category    12654 non-null  object
#  2   parameter   12654 non-null  object
#  3   mode        12654 non-null  object
#  4   powertrain  12654 non-null  object
#  5   year        12654 non-null  int64
#  6   unit        12654 non-null  object
#  7   value       12654 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 791.0+ KB

# %%
cols = df.columns

# %%
for i in cols:
    if isinstance(1, object):
        print(i)
        print(df[i].unique())
        print("------------------------------------------------------------------------")
# Out:
# region
# ['Australia' 'Austria' 'Belgium' 'Brazil' 'Bulgaria' 'Canada' 'Chile'
#  'China' 'Colombia' 'Costa Rica' 'Croatia' 'Cyprus' 'Czech Republic'
#  'Denmark' 'Estonia' 'EU27' 'Europe' 'Finland' 'France' 'Germany' 'Greece'
#  'Hungary' 'Iceland' 'India' 'Indonesia' 'Ireland' 'Israel' 'Italy'
#  'Japan' 'Korea' 'Latvia' 'Lithuania' 'Luxembourg' 'Mexico' 'Netherlands'
#  'New Zealand' 'Norway' 'Poland' 'Portugal' 'Rest of the world' 'Romania'
#  'Seychelles' 'Slovakia' 'Slovenia' 'South Africa' 'Spain' 'Sweden'
#  'Switzerland' 'Thailand' 'Turkiye' 'United Arab Emirates'
#  'United Kingdom' 'USA' 'World']
# ------------------------------------------------------------------------
# category
# ['Historical' 'Projection-STEPS' 'Projection-APS']
# ------------------------------------------------------------------------
# parameter
# ['EV stock share' 'EV sales share' 'EV sales' 'EV stock'
#  'EV charging points' 'Electricity demand' 'Oil displacement Mbd'
# ...

# %%
df[df['parameter'] =='Electricity demand']['region'].unique()
# Out:
# array(['China', 'Europe', 'India', 'Rest of the world', 'USA', 'World'],
#       dtype=object)

# %%
df[df['region'] == 'Indonesia']
# Out:
#          region    category           parameter mode               powertrain  \
# 6101  Indonesia  Historical  EV charging points   EV  Publicly available fast
# 6102  Indonesia  Historical  EV charging points   EV  Publicly available slow
# 6103  Indonesia  Historical  EV charging points   EV  Publicly available fast
# 6104  Indonesia  Historical  EV charging points   EV  Publicly available slow
# 6105  Indonesia  Historical  EV charging points   EV  Publicly available fast
# 6106  Indonesia  Historical  EV charging points   EV  Publicly available slow
# 6107  Indonesia  Historical  EV charging points   EV  Publicly available fast
# 6108  Indonesia  Historical  EV charging points   EV  Publicly available slow
#
#       year             unit  value
# 6101  2020  charging points   51.0
# 6102  2020  charging points   50.0
# 6103  2021  charging points  130.0
# 6104  2021  charging points   54.0
# 6105  2022  charging points  130.0
# 6106  2022  charging points  580.0
# ...

# %%
df[df['region'] == 'Thailand']
# Out:
#          region    category           parameter mode               powertrain  \
# 10207  Thailand  Historical  EV charging points   EV  Publicly available fast
# 10208  Thailand  Historical  EV charging points   EV  Publicly available slow
# 10209  Thailand  Historical  EV charging points   EV  Publicly available fast
# 10210  Thailand  Historical  EV charging points   EV  Publicly available slow
# 10211  Thailand  Historical  EV charging points   EV  Publicly available fast
# 10212  Thailand  Historical  EV charging points   EV  Publicly available slow
# 10213  Thailand  Historical  EV charging points   EV  Publicly available fast
# 10214  Thailand  Historical  EV charging points   EV  Publicly available slow
# 10215  Thailand  Historical  EV charging points   EV  Publicly available fast
# 10216  Thailand  Historical  EV charging points   EV  Publicly available slow
# 10217  Thailand  Historical  EV charging points   EV  Publicly available fast
# ...
